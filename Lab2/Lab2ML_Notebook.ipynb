# %%
import requests
vacancy_list = []
import matplotlib.pyplot as plt
import numpy as np

# %%
def parse_salary(sal):
    if sal == None:
        return 0
    if sal["to"] == None :
        return sal["from"]
    if sal["from"] == None:
        return sal["to"]
    return (sal["from"] + sal["to"])/2

# %%
for i in range(1,11):
    req = 'https://api.hh.ru/vacancies?text="big data" or "data science" or "data analyst" or "Big Data Specialist" or "machine learning" or  "data analytics" or "data engineer" or "data scientist" or "machine learning engineer" or "машинное обучение"&only_with_salary=true&per_page=100&pages=10&period=30&currency=RUR'
    req = req +'&page=' + str(i)
    r = requests.get(req)
    parsed_string = r.json()
    for item in parsed_string["items"]:
        vacancy = {"salary":None, "area":None, "name":None, "employer":None}
        vacancy["salary"] = parse_salary( item["salary"] )
        vacancy["area"] = item["area"]["name"]
        vacancy["name"]=item["name"]
        vacancy["employer"]=item["employer"]["name"]
        vacancy_list.append(vacancy)
    print (vacancy_list)
# Out:
# [{'salary': 80000, 'area': 'Москва', 'name': 'Системный аналитик', 'employer': 'ВижнЛабс (VisionLabs)'}, {'salary': 2500, 'area': 'Минск', 'name': 'PHP программист с перспективой Team-Lead / PM', 'employer': 'Метрика Девелопмент'}, {'salary': 200000, 'area': 'Нижний Новгород', 'name': 'Data Science Team Leader (г.Санкт-Петерубрг)', 'employer': 'Сбербанк'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Data Science Team Leader (г.Санкт-Петербург)', 'employer': 'Сбербанк'}, {'salary': 120000, 'area': 'Санкт-Петербург', 'name': 'PHP Developer', 'employer': 'Big Data Technologies'}, {'salary': 105000.0, 'area': 'Москва', 'name': 'Программист-разработчик Python', 'employer': 'Рокси'}, {'salary': 100000, 'area': 'Санкт-Петербург', 'name': 'Product Manager', 'employer': 'Big Data Technologies'}, {'salary': 80000, 'area': 'Москва', 'name': 'Программист C++', 'employer': 'Аником'}, {'salary': 80000, 'area': 'Санкт-Петербург', 'name': 'QA Engineer', 'employer': 'Behavox'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'DevOps Engineer', 'employer': 'Behavox'}, {'salary': 120000, 'area': 'Екатеринбург', 'name': 'Руководитель проекта BigData', 'employer': 'Магазин постоянных распродаж ГАЛАМАРТ Федеральная сеть магазинов'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'UX дизайнер', 'employer': 'Segmento'}, {'salary': 210000, 'area': 'Санкт-Петербург', 'name': 'Senior C#/.Net Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 110000.0, 'area': 'Нижний Новгород', 'name': 'Инженер-программист C++ (алгоритмы компьютерного зрения)', 'employer': 'V5 Systems'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Java Developer', 'employer': 'Behavox'}, {'salary': 4000.0, 'area': 'Санкт-Петербург', 'name': 'Senior Python Developer', 'employer': 'EMG Professionals'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Старший Java программист', 'employer': 'DSR, Группа Компаний'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Senior Scala Developer', 'employer': 'DSR, Группа Компаний'}, {'salary': 130000, 'area': 'Москва', 'name': 'Ведущий менеджер по продажам IT решений', 'employer': 'Группа компаний Смарт'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 200000, 'area': 'Москва', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 137500.0, 'area': 'Москва', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 137500.0, 'area': 'Санкт-Петербург', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 200000, 'area': 'Москва', 'name': 'Fullstack teamlead', 'employer': 'Алгоритмика'}, {'salary': 115000.0, 'area': 'Москва', 'name': 'Программист – математик', 'employer': 'Russ Outdoor'}, {'salary': 160000, 'area': 'Санкт-Петербург', 'name': 'Senior Front-End/JavaScript Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 70000, 'area': 'Новосибирск', 'name': 'Менеджер IT-проектов / Аналитик', 'employer': 'LIME'}, {'salary': 57500.0, 'area': 'Тольятти', 'name': 'Программист Scala / Java ( Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 75000.0, 'area': 'Тольятти', 'name': 'Ведущий программист Scala / Java ( Senior Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 120000, 'area': 'Москва', 'name': 'Менеджер тендерного отдела (подача тендерных заявок)', 'employer': 'АРЕС'}, {'salary': 300000.0, 'area': 'Алматы', 'name': 'Unity / Unreal Engine 4 разработчик', 'employer': 'Singularity Lab'}, {'salary': 60000, 'area': 'Ростов-на-Дону', 'name': 'Инженер технической поддержки', 'employer': 'МТС'}, {'salary': 30000, 'area': 'Казань', 'name': 'Специалист по работе с просроченной задолженностью', 'employer': 'ID Finance'}, {'salary': 230000, 'area': 'Москва', 'name': 'Senior Golang Developer', 'employer': 'Первый Мост'}, {'salary': 400, 'area': 'Минск', 'name': 'Уборщик производственных и служебных помещений', 'employer': 'Зауберклиник'}, {'salary': 5900.0, 'area': ' ...
# [{'salary': 80000, 'area': 'Москва', 'name': 'Системный аналитик', 'employer': 'ВижнЛабс (VisionLabs)'}, {'salary': 2500, 'area': 'Минск', 'name': 'PHP программист с перспективой Team-Lead / PM', 'employer': 'Метрика Девелопмент'}, {'salary': 200000, 'area': 'Нижний Новгород', 'name': 'Data Science Team Leader (г.Санкт-Петерубрг)', 'employer': 'Сбербанк'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Data Science Team Leader (г.Санкт-Петербург)', 'employer': 'Сбербанк'}, {'salary': 120000, 'area': 'Санкт-Петербург', 'name': 'PHP Developer', 'employer': 'Big Data Technologies'}, {'salary': 105000.0, 'area': 'Москва', 'name': 'Программист-разработчик Python', 'employer': 'Рокси'}, {'salary': 100000, 'area': 'Санкт-Петербург', 'name': 'Product Manager', 'employer': 'Big Data Technologies'}, {'salary': 80000, 'area': 'Москва', 'name': 'Программист C++', 'employer': 'Аником'}, {'salary': 80000, 'area': 'Санкт-Петербург', 'name': 'QA Engineer', 'employer': 'Behavox'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'DevOps Engineer', 'employer': 'Behavox'}, {'salary': 120000, 'area': 'Екатеринбург', 'name': 'Руководитель проекта BigData', 'employer': 'Магазин постоянных распродаж ГАЛАМАРТ Федеральная сеть магазинов'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'UX дизайнер', 'employer': 'Segmento'}, {'salary': 210000, 'area': 'Санкт-Петербург', 'name': 'Senior C#/.Net Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 110000.0, 'area': 'Нижний Новгород', 'name': 'Инженер-программист C++ (алгоритмы компьютерного зрения)', 'employer': 'V5 Systems'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Java Developer', 'employer': 'Behavox'}, {'salary': 4000.0, 'area': 'Санкт-Петербург', 'name': 'Senior Python Developer', 'employer': 'EMG Professionals'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Старший Java программист', 'employer': 'DSR, Группа Компаний'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Senior Scala Developer', 'employer': 'DSR, Группа Компаний'}, {'salary': 130000, 'area': 'Москва', 'name': 'Ведущий менеджер по продажам IT решений', 'employer': 'Группа компаний Смарт'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 200000, 'area': 'Москва', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 137500.0, 'area': 'Москва', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 137500.0, 'area': 'Санкт-Петербург', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 200000, 'area': 'Москва', 'name': 'Fullstack teamlead', 'employer': 'Алгоритмика'}, {'salary': 115000.0, 'area': 'Москва', 'name': 'Программист – математик', 'employer': 'Russ Outdoor'}, {'salary': 160000, 'area': 'Санкт-Петербург', 'name': 'Senior Front-End/JavaScript Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 70000, 'area': 'Новосибирск', 'name': 'Менеджер IT-проектов / Аналитик', 'employer': 'LIME'}, {'salary': 57500.0, 'area': 'Тольятти', 'name': 'Программист Scala / Java ( Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 75000.0, 'area': 'Тольятти', 'name': 'Ведущий программист Scala / Java ( Senior Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 120000, 'area': 'Москва', 'name': 'Менеджер тендерного отдела (подача тендерных заявок)', 'employer': 'АРЕС'}, {'salary': 300000.0, 'area': 'Алматы', 'name': 'Unity / Unreal Engine 4 разработчик', 'employer': 'Singularity Lab'}, {'salary': 60000, 'area': 'Ростов-на-Дону', 'name': 'Инженер технической поддержки', 'employer': 'МТС'}, {'salary': 30000, 'area': 'Казань', 'name': 'Специалист по работе с просроченной задолженностью', 'employer': 'ID Finance'}, {'salary': 230000, 'area': 'Москва', 'name': 'Senior Golang Developer', 'employer': 'Первый Мост'}, {'salary': 400, 'area': 'Минск', 'name': 'Уборщик производственных и служебных помещений', 'employer': 'Зауберклиник'}, {'salary': 5900.0, 'area': ' ...
# [{'salary': 80000, 'area': 'Москва', 'name': 'Системный аналитик', 'employer': 'ВижнЛабс (VisionLabs)'}, {'salary': 2500, 'area': 'Минск', 'name': 'PHP программист с перспективой Team-Lead / PM', 'employer': 'Метрика Девелопмент'}, {'salary': 200000, 'area': 'Нижний Новгород', 'name': 'Data Science Team Leader (г.Санкт-Петерубрг)', 'employer': 'Сбербанк'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Data Science Team Leader (г.Санкт-Петербург)', 'employer': 'Сбербанк'}, {'salary': 120000, 'area': 'Санкт-Петербург', 'name': 'PHP Developer', 'employer': 'Big Data Technologies'}, {'salary': 105000.0, 'area': 'Москва', 'name': 'Программист-разработчик Python', 'employer': 'Рокси'}, {'salary': 100000, 'area': 'Санкт-Петербург', 'name': 'Product Manager', 'employer': 'Big Data Technologies'}, {'salary': 80000, 'area': 'Москва', 'name': 'Программист C++', 'employer': 'Аником'}, {'salary': 80000, 'area': 'Санкт-Петербург', 'name': 'QA Engineer', 'employer': 'Behavox'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'DevOps Engineer', 'employer': 'Behavox'}, {'salary': 120000, 'area': 'Екатеринбург', 'name': 'Руководитель проекта BigData', 'employer': 'Магазин постоянных распродаж ГАЛАМАРТ Федеральная сеть магазинов'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'UX дизайнер', 'employer': 'Segmento'}, {'salary': 210000, 'area': 'Санкт-Петербург', 'name': 'Senior C#/.Net Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 110000.0, 'area': 'Нижний Новгород', 'name': 'Инженер-программист C++ (алгоритмы компьютерного зрения)', 'employer': 'V5 Systems'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Java Developer', 'employer': 'Behavox'}, {'salary': 4000.0, 'area': 'Санкт-Петербург', 'name': 'Senior Python Developer', 'employer': 'EMG Professionals'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Старший Java программист', 'employer': 'DSR, Группа Компаний'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Senior Scala Developer', 'employer': 'DSR, Группа Компаний'}, {'salary': 130000, 'area': 'Москва', 'name': 'Ведущий менеджер по продажам IT решений', 'employer': 'Группа компаний Смарт'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 200000, 'area': 'Москва', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 137500.0, 'area': 'Москва', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 137500.0, 'area': 'Санкт-Петербург', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 200000, 'area': 'Москва', 'name': 'Fullstack teamlead', 'employer': 'Алгоритмика'}, {'salary': 115000.0, 'area': 'Москва', 'name': 'Программист – математик', 'employer': 'Russ Outdoor'}, {'salary': 160000, 'area': 'Санкт-Петербург', 'name': 'Senior Front-End/JavaScript Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 70000, 'area': 'Новосибирск', 'name': 'Менеджер IT-проектов / Аналитик', 'employer': 'LIME'}, {'salary': 57500.0, 'area': 'Тольятти', 'name': 'Программист Scala / Java ( Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 75000.0, 'area': 'Тольятти', 'name': 'Ведущий программист Scala / Java ( Senior Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 120000, 'area': 'Москва', 'name': 'Менеджер тендерного отдела (подача тендерных заявок)', 'employer': 'АРЕС'}, {'salary': 300000.0, 'area': 'Алматы', 'name': 'Unity / Unreal Engine 4 разработчик', 'employer': 'Singularity Lab'}, {'salary': 60000, 'area': 'Ростов-на-Дону', 'name': 'Инженер технической поддержки', 'employer': 'МТС'}, {'salary': 30000, 'area': 'Казань', 'name': 'Специалист по работе с просроченной задолженностью', 'employer': 'ID Finance'}, {'salary': 230000, 'area': 'Москва', 'name': 'Senior Golang Developer', 'employer': 'Первый Мост'}, {'salary': 400, 'area': 'Минск', 'name': 'Уборщик производственных и служебных помещений', 'employer': 'Зауберклиник'}, {'salary': 5900.0, 'area': ' ...
# [{'salary': 80000, 'area': 'Москва', 'name': 'Системный аналитик', 'employer': 'ВижнЛабс (VisionLabs)'}, {'salary': 2500, 'area': 'Минск', 'name': 'PHP программист с перспективой Team-Lead / PM', 'employer': 'Метрика Девелопмент'}, {'salary': 200000, 'area': 'Нижний Новгород', 'name': 'Data Science Team Leader (г.Санкт-Петерубрг)', 'employer': 'Сбербанк'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Data Science Team Leader (г.Санкт-Петербург)', 'employer': 'Сбербанк'}, {'salary': 120000, 'area': 'Санкт-Петербург', 'name': 'PHP Developer', 'employer': 'Big Data Technologies'}, {'salary': 105000.0, 'area': 'Москва', 'name': 'Программист-разработчик Python', 'employer': 'Рокси'}, {'salary': 100000, 'area': 'Санкт-Петербург', 'name': 'Product Manager', 'employer': 'Big Data Technologies'}, {'salary': 80000, 'area': 'Москва', 'name': 'Программист C++', 'employer': 'Аником'}, {'salary': 80000, 'area': 'Санкт-Петербург', 'name': 'QA Engineer', 'employer': 'Behavox'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'DevOps Engineer', 'employer': 'Behavox'}, {'salary': 120000, 'area': 'Екатеринбург', 'name': 'Руководитель проекта BigData', 'employer': 'Магазин постоянных распродаж ГАЛАМАРТ Федеральная сеть магазинов'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'UX дизайнер', 'employer': 'Segmento'}, {'salary': 210000, 'area': 'Санкт-Петербург', 'name': 'Senior C#/.Net Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 110000.0, 'area': 'Нижний Новгород', 'name': 'Инженер-программист C++ (алгоритмы компьютерного зрения)', 'employer': 'V5 Systems'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Java Developer', 'employer': 'Behavox'}, {'salary': 4000.0, 'area': 'Санкт-Петербург', 'name': 'Senior Python Developer', 'employer': 'EMG Professionals'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Старший Java программист', 'employer': 'DSR, Группа Компаний'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Senior Scala Developer', 'employer': 'DSR, Группа Компаний'}, {'salary': 130000, 'area': 'Москва', 'name': 'Ведущий менеджер по продажам IT решений', 'employer': 'Группа компаний Смарт'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 200000, 'area': 'Москва', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 137500.0, 'area': 'Москва', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 137500.0, 'area': 'Санкт-Петербург', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 200000, 'area': 'Москва', 'name': 'Fullstack teamlead', 'employer': 'Алгоритмика'}, {'salary': 115000.0, 'area': 'Москва', 'name': 'Программист – математик', 'employer': 'Russ Outdoor'}, {'salary': 160000, 'area': 'Санкт-Петербург', 'name': 'Senior Front-End/JavaScript Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 70000, 'area': 'Новосибирск', 'name': 'Менеджер IT-проектов / Аналитик', 'employer': 'LIME'}, {'salary': 57500.0, 'area': 'Тольятти', 'name': 'Программист Scala / Java ( Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 75000.0, 'area': 'Тольятти', 'name': 'Ведущий программист Scala / Java ( Senior Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 120000, 'area': 'Москва', 'name': 'Менеджер тендерного отдела (подача тендерных заявок)', 'employer': 'АРЕС'}, {'salary': 300000.0, 'area': 'Алматы', 'name': 'Unity / Unreal Engine 4 разработчик', 'employer': 'Singularity Lab'}, {'salary': 60000, 'area': 'Ростов-на-Дону', 'name': 'Инженер технической поддержки', 'employer': 'МТС'}, {'salary': 30000, 'area': 'Казань', 'name': 'Специалист по работе с просроченной задолженностью', 'employer': 'ID Finance'}, {'salary': 230000, 'area': 'Москва', 'name': 'Senior Golang Developer', 'employer': 'Первый Мост'}, {'salary': 400, 'area': 'Минск', 'name': 'Уборщик производственных и служебных помещений', 'employer': 'Зауберклиник'}, {'salary': 5900.0, 'area': ' ...
# [{'salary': 80000, 'area': 'Москва', 'name': 'Системный аналитик', 'employer': 'ВижнЛабс (VisionLabs)'}, {'salary': 2500, 'area': 'Минск', 'name': 'PHP программист с перспективой Team-Lead / PM', 'employer': 'Метрика Девелопмент'}, {'salary': 200000, 'area': 'Нижний Новгород', 'name': 'Data Science Team Leader (г.Санкт-Петерубрг)', 'employer': 'Сбербанк'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Data Science Team Leader (г.Санкт-Петербург)', 'employer': 'Сбербанк'}, {'salary': 120000, 'area': 'Санкт-Петербург', 'name': 'PHP Developer', 'employer': 'Big Data Technologies'}, {'salary': 105000.0, 'area': 'Москва', 'name': 'Программист-разработчик Python', 'employer': 'Рокси'}, {'salary': 100000, 'area': 'Санкт-Петербург', 'name': 'Product Manager', 'employer': 'Big Data Technologies'}, {'salary': 80000, 'area': 'Москва', 'name': 'Программист C++', 'employer': 'Аником'}, {'salary': 80000, 'area': 'Санкт-Петербург', 'name': 'QA Engineer', 'employer': 'Behavox'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'DevOps Engineer', 'employer': 'Behavox'}, {'salary': 120000, 'area': 'Екатеринбург', 'name': 'Руководитель проекта BigData', 'employer': 'Магазин постоянных распродаж ГАЛАМАРТ Федеральная сеть магазинов'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'UX дизайнер', 'employer': 'Segmento'}, {'salary': 210000, 'area': 'Санкт-Петербург', 'name': 'Senior C#/.Net Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 110000.0, 'area': 'Нижний Новгород', 'name': 'Инженер-программист C++ (алгоритмы компьютерного зрения)', 'employer': 'V5 Systems'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Java Developer', 'employer': 'Behavox'}, {'salary': 4000.0, 'area': 'Санкт-Петербург', 'name': 'Senior Python Developer', 'employer': 'EMG Professionals'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Старший Java программист', 'employer': 'DSR, Группа Компаний'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Senior Scala Developer', 'employer': 'DSR, Группа Компаний'}, {'salary': 130000, 'area': 'Москва', 'name': 'Ведущий менеджер по продажам IT решений', 'employer': 'Группа компаний Смарт'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 200000, 'area': 'Москва', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 137500.0, 'area': 'Москва', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 137500.0, 'area': 'Санкт-Петербург', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 200000, 'area': 'Москва', 'name': 'Fullstack teamlead', 'employer': 'Алгоритмика'}, {'salary': 115000.0, 'area': 'Москва', 'name': 'Программист – математик', 'employer': 'Russ Outdoor'}, {'salary': 160000, 'area': 'Санкт-Петербург', 'name': 'Senior Front-End/JavaScript Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 70000, 'area': 'Новосибирск', 'name': 'Менеджер IT-проектов / Аналитик', 'employer': 'LIME'}, {'salary': 57500.0, 'area': 'Тольятти', 'name': 'Программист Scala / Java ( Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 75000.0, 'area': 'Тольятти', 'name': 'Ведущий программист Scala / Java ( Senior Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 120000, 'area': 'Москва', 'name': 'Менеджер тендерного отдела (подача тендерных заявок)', 'employer': 'АРЕС'}, {'salary': 300000.0, 'area': 'Алматы', 'name': 'Unity / Unreal Engine 4 разработчик', 'employer': 'Singularity Lab'}, {'salary': 60000, 'area': 'Ростов-на-Дону', 'name': 'Инженер технической поддержки', 'employer': 'МТС'}, {'salary': 30000, 'area': 'Казань', 'name': 'Специалист по работе с просроченной задолженностью', 'employer': 'ID Finance'}, {'salary': 230000, 'area': 'Москва', 'name': 'Senior Golang Developer', 'employer': 'Первый Мост'}, {'salary': 400, 'area': 'Минск', 'name': 'Уборщик производственных и служебных помещений', 'employer': 'Зауберклиник'}, {'salary': 5900.0, 'area': ' ...
# [{'salary': 80000, 'area': 'Москва', 'name': 'Системный аналитик', 'employer': 'ВижнЛабс (VisionLabs)'}, {'salary': 2500, 'area': 'Минск', 'name': 'PHP программист с перспективой Team-Lead / PM', 'employer': 'Метрика Девелопмент'}, {'salary': 200000, 'area': 'Нижний Новгород', 'name': 'Data Science Team Leader (г.Санкт-Петерубрг)', 'employer': 'Сбербанк'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Data Science Team Leader (г.Санкт-Петербург)', 'employer': 'Сбербанк'}, {'salary': 120000, 'area': 'Санкт-Петербург', 'name': 'PHP Developer', 'employer': 'Big Data Technologies'}, {'salary': 105000.0, 'area': 'Москва', 'name': 'Программист-разработчик Python', 'employer': 'Рокси'}, {'salary': 100000, 'area': 'Санкт-Петербург', 'name': 'Product Manager', 'employer': 'Big Data Technologies'}, {'salary': 80000, 'area': 'Москва', 'name': 'Программист C++', 'employer': 'Аником'}, {'salary': 80000, 'area': 'Санкт-Петербург', 'name': 'QA Engineer', 'employer': 'Behavox'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'DevOps Engineer', 'employer': 'Behavox'}, {'salary': 120000, 'area': 'Екатеринбург', 'name': 'Руководитель проекта BigData', 'employer': 'Магазин постоянных распродаж ГАЛАМАРТ Федеральная сеть магазинов'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'UX дизайнер', 'employer': 'Segmento'}, {'salary': 210000, 'area': 'Санкт-Петербург', 'name': 'Senior C#/.Net Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 110000.0, 'area': 'Нижний Новгород', 'name': 'Инженер-программист C++ (алгоритмы компьютерного зрения)', 'employer': 'V5 Systems'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Java Developer', 'employer': 'Behavox'}, {'salary': 4000.0, 'area': 'Санкт-Петербург', 'name': 'Senior Python Developer', 'employer': 'EMG Professionals'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Старший Java программист', 'employer': 'DSR, Группа Компаний'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Senior Scala Developer', 'employer': 'DSR, Группа Компаний'}, {'salary': 130000, 'area': 'Москва', 'name': 'Ведущий менеджер по продажам IT решений', 'employer': 'Группа компаний Смарт'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 200000, 'area': 'Москва', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 137500.0, 'area': 'Москва', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 137500.0, 'area': 'Санкт-Петербург', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 200000, 'area': 'Москва', 'name': 'Fullstack teamlead', 'employer': 'Алгоритмика'}, {'salary': 115000.0, 'area': 'Москва', 'name': 'Программист – математик', 'employer': 'Russ Outdoor'}, {'salary': 160000, 'area': 'Санкт-Петербург', 'name': 'Senior Front-End/JavaScript Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 70000, 'area': 'Новосибирск', 'name': 'Менеджер IT-проектов / Аналитик', 'employer': 'LIME'}, {'salary': 57500.0, 'area': 'Тольятти', 'name': 'Программист Scala / Java ( Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 75000.0, 'area': 'Тольятти', 'name': 'Ведущий программист Scala / Java ( Senior Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 120000, 'area': 'Москва', 'name': 'Менеджер тендерного отдела (подача тендерных заявок)', 'employer': 'АРЕС'}, {'salary': 300000.0, 'area': 'Алматы', 'name': 'Unity / Unreal Engine 4 разработчик', 'employer': 'Singularity Lab'}, {'salary': 60000, 'area': 'Ростов-на-Дону', 'name': 'Инженер технической поддержки', 'employer': 'МТС'}, {'salary': 30000, 'area': 'Казань', 'name': 'Специалист по работе с просроченной задолженностью', 'employer': 'ID Finance'}, {'salary': 230000, 'area': 'Москва', 'name': 'Senior Golang Developer', 'employer': 'Первый Мост'}, {'salary': 400, 'area': 'Минск', 'name': 'Уборщик производственных и служебных помещений', 'employer': 'Зауберклиник'}, {'salary': 5900.0, 'area': ' ...
# [{'salary': 80000, 'area': 'Москва', 'name': 'Системный аналитик', 'employer': 'ВижнЛабс (VisionLabs)'}, {'salary': 2500, 'area': 'Минск', 'name': 'PHP программист с перспективой Team-Lead / PM', 'employer': 'Метрика Девелопмент'}, {'salary': 200000, 'area': 'Нижний Новгород', 'name': 'Data Science Team Leader (г.Санкт-Петерубрг)', 'employer': 'Сбербанк'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Data Science Team Leader (г.Санкт-Петербург)', 'employer': 'Сбербанк'}, {'salary': 120000, 'area': 'Санкт-Петербург', 'name': 'PHP Developer', 'employer': 'Big Data Technologies'}, {'salary': 105000.0, 'area': 'Москва', 'name': 'Программист-разработчик Python', 'employer': 'Рокси'}, {'salary': 100000, 'area': 'Санкт-Петербург', 'name': 'Product Manager', 'employer': 'Big Data Technologies'}, {'salary': 80000, 'area': 'Москва', 'name': 'Программист C++', 'employer': 'Аником'}, {'salary': 80000, 'area': 'Санкт-Петербург', 'name': 'QA Engineer', 'employer': 'Behavox'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'DevOps Engineer', 'employer': 'Behavox'}, {'salary': 120000, 'area': 'Екатеринбург', 'name': 'Руководитель проекта BigData', 'employer': 'Магазин постоянных распродаж ГАЛАМАРТ Федеральная сеть магазинов'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'UX дизайнер', 'employer': 'Segmento'}, {'salary': 210000, 'area': 'Санкт-Петербург', 'name': 'Senior C#/.Net Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 110000.0, 'area': 'Нижний Новгород', 'name': 'Инженер-программист C++ (алгоритмы компьютерного зрения)', 'employer': 'V5 Systems'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Java Developer', 'employer': 'Behavox'}, {'salary': 4000.0, 'area': 'Санкт-Петербург', 'name': 'Senior Python Developer', 'employer': 'EMG Professionals'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Старший Java программист', 'employer': 'DSR, Группа Компаний'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Senior Scala Developer', 'employer': 'DSR, Группа Компаний'}, {'salary': 130000, 'area': 'Москва', 'name': 'Ведущий менеджер по продажам IT решений', 'employer': 'Группа компаний Смарт'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 200000, 'area': 'Москва', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 137500.0, 'area': 'Москва', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 137500.0, 'area': 'Санкт-Петербург', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 200000, 'area': 'Москва', 'name': 'Fullstack teamlead', 'employer': 'Алгоритмика'}, {'salary': 115000.0, 'area': 'Москва', 'name': 'Программист – математик', 'employer': 'Russ Outdoor'}, {'salary': 160000, 'area': 'Санкт-Петербург', 'name': 'Senior Front-End/JavaScript Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 70000, 'area': 'Новосибирск', 'name': 'Менеджер IT-проектов / Аналитик', 'employer': 'LIME'}, {'salary': 57500.0, 'area': 'Тольятти', 'name': 'Программист Scala / Java ( Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 75000.0, 'area': 'Тольятти', 'name': 'Ведущий программист Scala / Java ( Senior Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 120000, 'area': 'Москва', 'name': 'Менеджер тендерного отдела (подача тендерных заявок)', 'employer': 'АРЕС'}, {'salary': 300000.0, 'area': 'Алматы', 'name': 'Unity / Unreal Engine 4 разработчик', 'employer': 'Singularity Lab'}, {'salary': 60000, 'area': 'Ростов-на-Дону', 'name': 'Инженер технической поддержки', 'employer': 'МТС'}, {'salary': 30000, 'area': 'Казань', 'name': 'Специалист по работе с просроченной задолженностью', 'employer': 'ID Finance'}, {'salary': 230000, 'area': 'Москва', 'name': 'Senior Golang Developer', 'employer': 'Первый Мост'}, {'salary': 400, 'area': 'Минск', 'name': 'Уборщик производственных и служебных помещений', 'employer': 'Зауберклиник'}, {'salary': 5900.0, 'area': ' ...
# [{'salary': 80000, 'area': 'Москва', 'name': 'Системный аналитик', 'employer': 'ВижнЛабс (VisionLabs)'}, {'salary': 2500, 'area': 'Минск', 'name': 'PHP программист с перспективой Team-Lead / PM', 'employer': 'Метрика Девелопмент'}, {'salary': 200000, 'area': 'Нижний Новгород', 'name': 'Data Science Team Leader (г.Санкт-Петерубрг)', 'employer': 'Сбербанк'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Data Science Team Leader (г.Санкт-Петербург)', 'employer': 'Сбербанк'}, {'salary': 120000, 'area': 'Санкт-Петербург', 'name': 'PHP Developer', 'employer': 'Big Data Technologies'}, {'salary': 105000.0, 'area': 'Москва', 'name': 'Программист-разработчик Python', 'employer': 'Рокси'}, {'salary': 100000, 'area': 'Санкт-Петербург', 'name': 'Product Manager', 'employer': 'Big Data Technologies'}, {'salary': 80000, 'area': 'Москва', 'name': 'Программист C++', 'employer': 'Аником'}, {'salary': 80000, 'area': 'Санкт-Петербург', 'name': 'QA Engineer', 'employer': 'Behavox'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'DevOps Engineer', 'employer': 'Behavox'}, {'salary': 120000, 'area': 'Екатеринбург', 'name': 'Руководитель проекта BigData', 'employer': 'Магазин постоянных распродаж ГАЛАМАРТ Федеральная сеть магазинов'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'UX дизайнер', 'employer': 'Segmento'}, {'salary': 210000, 'area': 'Санкт-Петербург', 'name': 'Senior C#/.Net Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 110000.0, 'area': 'Нижний Новгород', 'name': 'Инженер-программист C++ (алгоритмы компьютерного зрения)', 'employer': 'V5 Systems'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Java Developer', 'employer': 'Behavox'}, {'salary': 4000.0, 'area': 'Санкт-Петербург', 'name': 'Senior Python Developer', 'employer': 'EMG Professionals'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Старший Java программист', 'employer': 'DSR, Группа Компаний'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Senior Scala Developer', 'employer': 'DSR, Группа Компаний'}, {'salary': 130000, 'area': 'Москва', 'name': 'Ведущий менеджер по продажам IT решений', 'employer': 'Группа компаний Смарт'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 200000, 'area': 'Москва', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 137500.0, 'area': 'Москва', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 137500.0, 'area': 'Санкт-Петербург', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 200000, 'area': 'Москва', 'name': 'Fullstack teamlead', 'employer': 'Алгоритмика'}, {'salary': 115000.0, 'area': 'Москва', 'name': 'Программист – математик', 'employer': 'Russ Outdoor'}, {'salary': 160000, 'area': 'Санкт-Петербург', 'name': 'Senior Front-End/JavaScript Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 70000, 'area': 'Новосибирск', 'name': 'Менеджер IT-проектов / Аналитик', 'employer': 'LIME'}, {'salary': 57500.0, 'area': 'Тольятти', 'name': 'Программист Scala / Java ( Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 75000.0, 'area': 'Тольятти', 'name': 'Ведущий программист Scala / Java ( Senior Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 120000, 'area': 'Москва', 'name': 'Менеджер тендерного отдела (подача тендерных заявок)', 'employer': 'АРЕС'}, {'salary': 300000.0, 'area': 'Алматы', 'name': 'Unity / Unreal Engine 4 разработчик', 'employer': 'Singularity Lab'}, {'salary': 60000, 'area': 'Ростов-на-Дону', 'name': 'Инженер технической поддержки', 'employer': 'МТС'}, {'salary': 30000, 'area': 'Казань', 'name': 'Специалист по работе с просроченной задолженностью', 'employer': 'ID Finance'}, {'salary': 230000, 'area': 'Москва', 'name': 'Senior Golang Developer', 'employer': 'Первый Мост'}, {'salary': 400, 'area': 'Минск', 'name': 'Уборщик производственных и служебных помещений', 'employer': 'Зауберклиник'}, {'salary': 5900.0, 'area': ' ...
# [{'salary': 80000, 'area': 'Москва', 'name': 'Системный аналитик', 'employer': 'ВижнЛабс (VisionLabs)'}, {'salary': 2500, 'area': 'Минск', 'name': 'PHP программист с перспективой Team-Lead / PM', 'employer': 'Метрика Девелопмент'}, {'salary': 200000, 'area': 'Нижний Новгород', 'name': 'Data Science Team Leader (г.Санкт-Петерубрг)', 'employer': 'Сбербанк'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Data Science Team Leader (г.Санкт-Петербург)', 'employer': 'Сбербанк'}, {'salary': 120000, 'area': 'Санкт-Петербург', 'name': 'PHP Developer', 'employer': 'Big Data Technologies'}, {'salary': 105000.0, 'area': 'Москва', 'name': 'Программист-разработчик Python', 'employer': 'Рокси'}, {'salary': 100000, 'area': 'Санкт-Петербург', 'name': 'Product Manager', 'employer': 'Big Data Technologies'}, {'salary': 80000, 'area': 'Москва', 'name': 'Программист C++', 'employer': 'Аником'}, {'salary': 80000, 'area': 'Санкт-Петербург', 'name': 'QA Engineer', 'employer': 'Behavox'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'DevOps Engineer', 'employer': 'Behavox'}, {'salary': 120000, 'area': 'Екатеринбург', 'name': 'Руководитель проекта BigData', 'employer': 'Магазин постоянных распродаж ГАЛАМАРТ Федеральная сеть магазинов'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'UX дизайнер', 'employer': 'Segmento'}, {'salary': 210000, 'area': 'Санкт-Петербург', 'name': 'Senior C#/.Net Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 110000.0, 'area': 'Нижний Новгород', 'name': 'Инженер-программист C++ (алгоритмы компьютерного зрения)', 'employer': 'V5 Systems'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Java Developer', 'employer': 'Behavox'}, {'salary': 4000.0, 'area': 'Санкт-Петербург', 'name': 'Senior Python Developer', 'employer': 'EMG Professionals'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Старший Java программист', 'employer': 'DSR, Группа Компаний'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Senior Scala Developer', 'employer': 'DSR, Группа Компаний'}, {'salary': 130000, 'area': 'Москва', 'name': 'Ведущий менеджер по продажам IT решений', 'employer': 'Группа компаний Смарт'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 200000, 'area': 'Москва', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 137500.0, 'area': 'Москва', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 137500.0, 'area': 'Санкт-Петербург', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 200000, 'area': 'Москва', 'name': 'Fullstack teamlead', 'employer': 'Алгоритмика'}, {'salary': 115000.0, 'area': 'Москва', 'name': 'Программист – математик', 'employer': 'Russ Outdoor'}, {'salary': 160000, 'area': 'Санкт-Петербург', 'name': 'Senior Front-End/JavaScript Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 70000, 'area': 'Новосибирск', 'name': 'Менеджер IT-проектов / Аналитик', 'employer': 'LIME'}, {'salary': 57500.0, 'area': 'Тольятти', 'name': 'Программист Scala / Java ( Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 75000.0, 'area': 'Тольятти', 'name': 'Ведущий программист Scala / Java ( Senior Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 120000, 'area': 'Москва', 'name': 'Менеджер тендерного отдела (подача тендерных заявок)', 'employer': 'АРЕС'}, {'salary': 300000.0, 'area': 'Алматы', 'name': 'Unity / Unreal Engine 4 разработчик', 'employer': 'Singularity Lab'}, {'salary': 60000, 'area': 'Ростов-на-Дону', 'name': 'Инженер технической поддержки', 'employer': 'МТС'}, {'salary': 30000, 'area': 'Казань', 'name': 'Специалист по работе с просроченной задолженностью', 'employer': 'ID Finance'}, {'salary': 230000, 'area': 'Москва', 'name': 'Senior Golang Developer', 'employer': 'Первый Мост'}, {'salary': 400, 'area': 'Минск', 'name': 'Уборщик производственных и служебных помещений', 'employer': 'Зауберклиник'}, {'salary': 5900.0, 'area': ' ...
# [{'salary': 80000, 'area': 'Москва', 'name': 'Системный аналитик', 'employer': 'ВижнЛабс (VisionLabs)'}, {'salary': 2500, 'area': 'Минск', 'name': 'PHP программист с перспективой Team-Lead / PM', 'employer': 'Метрика Девелопмент'}, {'salary': 200000, 'area': 'Нижний Новгород', 'name': 'Data Science Team Leader (г.Санкт-Петерубрг)', 'employer': 'Сбербанк'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Data Science Team Leader (г.Санкт-Петербург)', 'employer': 'Сбербанк'}, {'salary': 120000, 'area': 'Санкт-Петербург', 'name': 'PHP Developer', 'employer': 'Big Data Technologies'}, {'salary': 105000.0, 'area': 'Москва', 'name': 'Программист-разработчик Python', 'employer': 'Рокси'}, {'salary': 100000, 'area': 'Санкт-Петербург', 'name': 'Product Manager', 'employer': 'Big Data Technologies'}, {'salary': 80000, 'area': 'Москва', 'name': 'Программист C++', 'employer': 'Аником'}, {'salary': 80000, 'area': 'Санкт-Петербург', 'name': 'QA Engineer', 'employer': 'Behavox'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'DevOps Engineer', 'employer': 'Behavox'}, {'salary': 120000, 'area': 'Екатеринбург', 'name': 'Руководитель проекта BigData', 'employer': 'Магазин постоянных распродаж ГАЛАМАРТ Федеральная сеть магазинов'}, {'salary': 150000, 'area': 'Санкт-Петербург', 'name': 'UX дизайнер', 'employer': 'Segmento'}, {'salary': 210000, 'area': 'Санкт-Петербург', 'name': 'Senior C#/.Net Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 110000.0, 'area': 'Нижний Новгород', 'name': 'Инженер-программист C++ (алгоритмы компьютерного зрения)', 'employer': 'V5 Systems'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Java Developer', 'employer': 'Behavox'}, {'salary': 4000.0, 'area': 'Санкт-Петербург', 'name': 'Senior Python Developer', 'employer': 'EMG Professionals'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Старший Java программист', 'employer': 'DSR, Группа Компаний'}, {'salary': 1850.0, 'area': 'Воронеж', 'name': 'Senior Scala Developer', 'employer': 'DSR, Группа Компаний'}, {'salary': 130000, 'area': 'Москва', 'name': 'Ведущий менеджер по продажам IT решений', 'employer': 'Группа компаний Смарт'}, {'salary': 200000, 'area': 'Санкт-Петербург', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 200000, 'area': 'Москва', 'name': 'Senior Blockchain Engineer', 'employer': 'АРЕС'}, {'salary': 137500.0, 'area': 'Москва', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 137500.0, 'area': 'Санкт-Петербург', 'name': 'Количественный аналитик', 'employer': 'QuantNet'}, {'salary': 200000, 'area': 'Москва', 'name': 'Fullstack teamlead', 'employer': 'Алгоритмика'}, {'salary': 115000.0, 'area': 'Москва', 'name': 'Программист – математик', 'employer': 'Russ Outdoor'}, {'salary': 160000, 'area': 'Санкт-Петербург', 'name': 'Senior Front-End/JavaScript Developer', 'employer': 'ООО «Аптик СПб»'}, {'salary': 70000, 'area': 'Новосибирск', 'name': 'Менеджер IT-проектов / Аналитик', 'employer': 'LIME'}, {'salary': 57500.0, 'area': 'Тольятти', 'name': 'Программист Scala / Java ( Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 75000.0, 'area': 'Тольятти', 'name': 'Ведущий программист Scala / Java ( Senior Scala / Java Developer )', 'employer': 'Квартплата 24'}, {'salary': 120000, 'area': 'Москва', 'name': 'Менеджер тендерного отдела (подача тендерных заявок)', 'employer': 'АРЕС'}, {'salary': 300000.0, 'area': 'Алматы', 'name': 'Unity / Unreal Engine 4 разработчик', 'employer': 'Singularity Lab'}, {'salary': 60000, 'area': 'Ростов-на-Дону', 'name': 'Инженер технической поддержки', 'employer': 'МТС'}, {'salary': 30000, 'area': 'Казань', 'name': 'Специалист по работе с просроченной задолженностью', 'employer': 'ID Finance'}, {'salary': 230000, 'area': 'Москва', 'name': 'Senior Golang Developer', 'employer': 'Первый Мост'}, {'salary': 400, 'area': 'Минск', 'name': 'Уборщик производственных и служебных помещений', 'employer': 'Зауберклиник'}, {'salary': 5900.0, 'area': ' ...

# %% [markdown]
# for item in parsed_string["items"]:
#     vacancy = {"salary":None, "area":None, "name":None, "employer":None}
#     vacancy["salary"] = parse_salary( item["salary"] )
#     vacancy["area"] = item["area"]["name"]
#     vacancy["name"]=item["name"]
#     vacancy["employer"]=item["employer"]["name"]
#     vacancy_list.append(vacancy)
#     print (vacancy_list)

# %%
vacancy = {80:0, 120:0, 150:0, 200:0, 300:0, 310:0}

for vac in vacancy_list:
    if vac["salary"] < 80000:
        vacancy[80] = vacancy[80] + 1
        continue
    if vac["salary"] < 120000 :
        vacancy[120] = vacancy[120] + 1
        continue
    if vac["salary"] < 150000 :
        vacancy[150] = vacancy[150] + 1
        continue  
    if vac["salary"] < 200000 :
        vacancy[200] = vacancy[200] + 1
        continue
    if vac["salary"] < 300000 :
        vacancy[300] = vacancy[300] + 1
        continue
    vacancy[310] = vacancy[310] + 1 #зарплаты большие 300т.р.
print(vacancy)
# Out:
# {80: 314, 120: 130, 150: 90, 200: 92, 300: 62, 310: 8}

# %%
dict_vacancy = {}
for vac in vacancy_list:
    dict_vacancy[vac["name"]]=dict_vacancy.get(vac["name"],0)+1
tmp = dict((k,v) for k,v in dict_vacancy.items() if v>4 )
print (tmp)
# Out:
# {'Системный аналитик': 8, 'DevOps Engineer': 12, 'Senior Java Developer': 20, 'Java Developer': 6, 'Разработчик С++ (Лимассол, Кипр)': 8, 'Разработчик С++': 6, 'Ведущий С++ разработчик (Лимассол, Кипр)': 8, 'Программист-разработчик': 6, 'Javascript/Frontend/PHP-Fullstack программист': 6, 'Старший специалист по продажам корпоративным клиентам': 12, 'Frontend Developer': 10, 'Руководитель направления "Креативные интеллектуальные технологии"': 8, 'Blockchain Chief Architect - $8250/month - REMOTE WORK': 10, 'Software Architect (RoR, Java, .NET, Front End, PHP, ) - $5000/month - REMOTE WORK': 10, 'Software Engineer (Java, C++, .NET, Python, Front End) - $2500/month - REMOTE WORK': 14, 'Quant Analyst / Трейдер-разработчик': 10, 'Ведущий менеджер по продажам': 12}

# %% [raw]
# print (vacancy)

# %%
bins = [x*1000 for x in vacancy.keys()]
y_pos = np.arange(len(vacancy.keys()))
vals = [x for x in vacancy.values()]
plt.bar(y_pos, vals, color='blue', align='edge', width=-0.8)
plt.xticks(y_pos, bins)
plt.title("Гистограмма зависимости количества вакансий от зарплаты")
plt.xlabel("Зарплата")
plt.ylabel("Количество вакансий")

plt.show()

# %%
vals = [x for x in tmp.values()]
keys = [x for x in tmp.keys()]
y_pos = np.arange(len(vals))
plt.barh(y_pos,vals, color='pink')
plt.yticks(y_pos, keys)
plt.xticks(y_pos, range(0, max(vals) + 1, 1))
plt.title("Количество вакансий по названиям")
plt.xlabel("Количество предложений")
plt.show()
